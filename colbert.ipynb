# %% [markdown]
# <a href="https://colab.research.google.com/github/meti-94/BERT-QA/blob/main/colbert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers -q
# !pip uninstall -y tensorflow -q
# !pip install fuzzywuzzy[speedup] -q
# !pip install networkx -q
# !pip install pytorch-crf -q
# !pip install pattern -q
import nltk
nltk.download('omw-1.4')
# Out:
#      |████████████████████████████████| 5.8 MB 25.7 MB/s
#      |████████████████████████████████| 182 kB 55.1 MB/s
#      |████████████████████████████████| 7.6 MB 46.8 MB/s
#      |████████████████████████████████| 174 kB 58.4 MB/s
#      |████████████████████████████████| 2.2 MB 53.7 MB/s
#      |████████████████████████████████| 22.2 MB 1.1 MB/s
#      |████████████████████████████████| 88 kB 8.8 MB/s
#      |████████████████████████████████| 81 kB 12.1 MB/s
#      |████████████████████████████████| 5.6 MB 29.8 MB/s
#      |████████████████████████████████| 5.6 MB 64.5 MB/s
#      |████████████████████████████████| 348 kB 70.6 MB/s
#      |████████████████████████████████| 100 kB 11.9 MB/s
#      |████████████████████████████████| 4.0 MB 57.6 MB/s
#   Building wheel for pattern (setup.py) ... done
#   Building wheel for mysqlclient (setup.py) ... done
#   Building wheel for python-docx (setup.py) ... done
#   Building wheel for sgmllib3k (setup.py) ... done
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
# !git clone https://github.com/meti-94/BERT-QA.git
# Out:
# Cloning into 'BERT-QA'...
# remote: Enumerating objects: 610, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 610 (delta 34), reused 58 (delta 20), pack-reused 531
# Receiving objects: 100% (610/610), 117.31 MiB | 16.35 MiB/s, done.
# Resolving deltas: 100% (269/269), done.

# %%
# %cd /content/BERT-QA/src
# model types : [MultiDepthNodeEdgeDetector, BertLSTMCRF, BertCNN, NodeEdgeDetector]
# cross validation: [True, False]
# !python train.py NodeEdgeDetector False
# Out:
# /content/BERT-QA/src
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/config.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 139840545820240 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d.lock
# DEBUG:filelock:Lock 139840545820240 acquired on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /bert-base-uncased/resolve/main/config.json HTTP/1.1" 200 570
# Downloading: 100% 570/570 [00:00<00:00, 533kB/s]
# DEBUG:filelock:Attempting to release lock 139840545820240 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d.lock
# DEBUG:filelock:Lock 139840545820240 released on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/45a2321a7ecfdaaf60a6c1fd7f5463994cc8907d.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /bert-base-uncased/resolve/main/pytorch_model.bin HTTP/1.1" 302 0
# DEBUG:filelock:Attempting to acquire lock 139840545818656 on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/097417381d6c7230bd9e3557456d726de6e83245ec8b24f529f60198a67b203a.lock
# DEBUG:filelock:Lock 139840545818656 acquired on /root/.cache/huggingface/hub/models--bert-base-uncased/blobs/097417381d6c7230bd9e3557456d726de6e83245ec8b24f529f60198a67b203a.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cdn-lfs.huggingface.co:443
# DEBUG:urllib3.connectionpool:https://cdn-lfs.huggingface.co:443 "GET /bert-base-uncased/097417381d6c7230bd9e3557456d726de6e83245ec8b24f529f60198a67b203a?response-content-disposition=attachment%3B%20filename%3D%22pytorch_model.bin%22&Expires=1671001224&Policy=eyJTdGF0ZW1lbnQiOlt7IlJlc291cmNlIjoiaHR0cHM6Ly9jZG4tbGZzLmh1Z2dpbmdmYWNlLmNvL2JlcnQtYmFzZS11bmNhc2VkLzA5NzQxNzM4MWQ2YzcyMzBiZDllMzU1NzQ1NmQ3MjZkZTZlODMyNDVlYzhiMjRmNTI5ZjYwMTk4YTY3YjIwM2E~cmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvb
# INFO:root:Epoch number: 3 Train Loss is equal: 23.02886199951172
# Eval Epoch Number 3: 100% 9/9 [00:01<00:00,  6.80it/s]
# INFO:root:Epoch number: 3 Eval Loss is equal: 17.591787338256836
# Train Epoch Number 4: 100% 50/50 [00:25<00:00,  1.94it/s]
# INFO:root:Epoch number: 4 Train Loss is equal: 18.572093963623047
# Eval Epoch Number 4: 100% 9/9 [00:01<00:00,  6.82it/s]
# INFO:root:Epoch number: 4 Eval Loss is equal: 16.396406173706055
# Train Epoch Number 5: 100% 50/50 [00:26<00:00,  1.92it/s]
# INFO:root:Epoch number: 5 Train Loss is equal: 14.690845489501953
# Eval Epoch Number 5: 100% 9/9 [00:01<00:00,  6.74it/s]
# INFO:root:Epoch number: 5 Eval Loss is equal: 15.246975898742676
# Train Epoch Number 6: 100% 50/50 [00:26<00:00,  1.91it/s]
# INFO:root:Epoch number: 6 Train Loss is equal: 12.051478385925293
# Eval Epoch Number 6: 100% 9/9 [00:01<00:00,  6.76it/s]
# INFO:root:Epoch number: 6 Eval Loss is equal: 13.703764915466309
# Predicting ...: 100% 51/51 [00:04<00:00, 12.71it/s]
# INFO:root:Dataset-wide F1, precision and recall:
# INFO:root:0.9897923266455473, 0.9885744419054315, 0.9910132158590308
# INFO:root:Averaged F1, precision and recall:
# INFO:root:0.9883173510972775, 0.9880836577418628, 0.988551155021273
# INFO:root:Span accuracy
# INFO:root:0.9838097141714971
# INFO:root:Dataset-wide F1, precision and recall:
# INFO:root:0.9928969890163196, 0.9972854458133222, 0.9885469849592935
# INFO:root:Averaged F1, precision and recall:
# INFO:root:0.9951548417627089, 0.9977765721519471, 0.992546852840677
# INFO:root:Span accuracy
# INFO:root:0.9730161902858285
# Question                    Node               Edge
# --------------------------  -----------------  --------------------
# Where was Bill Gates Born?  ['bill', 'gates']  ['was', 'born', '?']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/reverb_wikipedia_tuples-1.1.txt /content/

# %%
# !pip install python-terrier -q
# !pip install --upgrade git+https://github.com/terrierteam/pyterrier_colbert.git -q
import sys

COLAB='google.colab' in sys.modules

try:
  import faiss
  faiss.get_num_gpus()
except:
  if COLAB:
    print('Installing faiss-gpu from pip ')
    # !pip install faiss-gpu==1.6.3
  else:
    print('Installing faiss-gpu via Conda')
    # !conda install -c pytorch faiss-gpu

import faiss
assert faiss.get_num_gpus() > 0
# Out:
#      |████████████████████████████████| 102 kB 37.9 MB/s
#      |████████████████████████████████| 1.5 MB 63.9 MB/s
#      |████████████████████████████████| 69 kB 9.5 MB/s
#      |████████████████████████████████| 311 kB 71.3 MB/s
#      |████████████████████████████████| 46 kB 5.1 MB/s
#      |████████████████████████████████| 286 kB 70.8 MB/s
#      |████████████████████████████████| 45 kB 3.5 MB/s
#      |████████████████████████████████| 133 kB 77.9 MB/s
#      |████████████████████████████████| 293 kB 80.0 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 1.2 MB 65.4 MB/s
#      |████████████████████████████████| 72 kB 1.0 MB/s
#   Building wheel for python-terrier (setup.py) ... done
#   Building wheel for ir-measures (setup.py) ... done
#   Building wheel for cwl-eval (setup.py) ... done
#   Building wheel for cbor (setup.py) ... done
#   Building wheel for unlzw3 (PEP 517) ... done
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Building wheel for chest (setup.py) ... done
#   Building wheel for sklearn (setup.py) ... done
#   Building wheel for wget (setup.py) ... done
#      |████████████████████████████████| 52 kB 965 kB/s
#      |████████████████████████████████| 16.5 MB 47.0 MB/s
#      |████████████████████████████████| 147 kB 73.8 MB/s
#      |████████████████████████████████| 82 kB 582 kB/s
#      |████████████████████████████████| 575 kB 57.8 MB/s
#      |████████████████████████████████| 79 kB 10.7 MB/s
#      |████████████████████████████████| 182 kB 82.6 MB/s
#      |████████████████████████████████| 209 kB 80.4 MB/s
#      |████████████████████████████████| 78 kB 10.0 MB/s
#      |████████████████████████████████| 147 kB 80.2 MB/s
#      |████████████████████████████████| 146 kB 83.0 MB/s
#      |████████████████████████████████| 55 kB 4.7 MB/s
#      |████████████████████████████████| 62 kB 1.6 MB/s
#   Building wheel for pyterrier-colbert (setup.py) ... done
#   Building wheel for ColBERT (setup.py) ... done
#   Building wheel for databricks-cli (setup.py) ... done
# Installing faiss-gpu from pip
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting faiss-gpu==1.6.3
#   Downloading faiss_gpu-1.6.3-cp38-cp38-manylinux2010_x86_64.whl (35.5 MB)
#      |████████████████████████████████| 35.5 MB 1.2 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from faiss-gpu==1.6.3) (1.21.6)
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.6.3

# %%
import pyterrier as pt
pt.init()
checkpoint="http://www.dcs.gla.ac.uk/~craigm/colbert.dnn.zip"
# !rm -rf /content/colbertindex
import pyterrier_colbert.indexing
indexer = pyterrier_colbert.indexing.ColBERTIndexer(checkpoint, "/content", "colbertindex", chunksize=3)
# indexer.index(pt.get_dataset("irds:vaswani").get_corpus_iter())
# Out:
# terrier-assemblies 5.7 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.7 jar not found, downloading to /root/.pyterrier...
# Done
# PyTerrier 0.9.1 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7

# %%
import pandas as pd
path = '/content/reverb_wikipedia_tuples-1.1.txt'
df = pd.read_csv(path, sep='\t', header=None)
reverb_columns_name = ['ExID', 'arg1', 'rel', 'arg2', 'narg1', 'nrel', 'narg2', 'csents', 'conf', 'urls']
df.columns = reverb_columns_name
df = df.dropna()
df = df.drop_duplicates()
df['normal_text'] = df.apply(lambda row:' '.join([row['narg1'], row['nrel'], row['narg2']]).strip(), axis=1)
df['text'] = df.apply(lambda row:' '.join([row['arg1'], row['rel'], row['arg2']]).strip(), axis=1)
df = df[['normal_text', 'text']]
df['docno'] = (df.index).astype(str)
df
# Out:
#                                               normal_text  \
# 0                                $ 10 be deduct for board
# 1                                 $ 10,000 come from j.j.
# 2       $ 13.8 million have be raise for construction ...
# 3                          $ 15.3 million be pay to japan
# 4                      $ 16,896 be need just for dredging
# ...                                                   ...
# 407242                    zinc be an ingredient in enzyte
# 407243                   zinc acetate consist of zn2+ ion
# 407244     zinc concentrate normally contain zinc sulfide
# 407245               zone 3 be north of the arctic circle
# 407246              zwieback be produce in friedrichsdorf
#
#                                                      text   docno
# 0                             $ 10 was deducted for board       0
# 1                                 $ 10,000 came from J.J.       1
# 2       $ 13.8 million had been raised for constructio...       2
# 3                        $ 15.3 million was paid to Japan       3
# 4                   $ 16,896 was needed just for dredging       4
# ...                                                   ...     ...
# 407242                    zinc is an ingredient in Enzyte  407242
# 407243                 zinc acetate consists of Zn2+ ions  407243
# 407244    zinc concentrate normally contains zinc sulfide  407244
# 407245               zone 3 is north of the Arctic Circle  407245
# 407246            zwieback was produced in Friedrichsdorf  407246
#
# [407236 rows x 3 columns]

# %%
indexer.index(df[['text', 'docno']].to_dict(orient="records"))
# Out:
# [Dec 11, 14:10:48] [0] 		 #> Local args.bsize = 128
# [Dec 11, 14:10:48] [0] 		 #> args.index_root = /content
# [Dec 11, 14:10:48] [0] 		 #> self.possible_subset_sizes = [69905]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing ColBERT: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing ColBERT from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ColBERT from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ColBERT were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['linear.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [Dec 11, 14:10:52] #> Loading model checkpoint.
# [Dec 11, 14:10:52] #> Loading checkpoint http://www.dcs.gla.ac.uk/~craigm/colbert.dnn.zip
# Downloading: "http://www.dcs.gla.ac.uk/~craigm/colbert.dnn.zip" to /root/.cache/torch/hub/checkpoints/colbert.dnn.zip
#   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# /usr/local/lib/python3.8/dist-packages/torch/hub.py:651: UserWarning: Falling back to the old format < 1.6. This support will be deprecated in favor of default zipfile format introduced in 1.6. Please redo torch.save() to save it in the new zipfile format.
#   warnings.warn('Falling back to the old format < 1.6. This support will be '
# [Dec 11, 14:12:30] #> checkpoint['epoch'] = 0
# [Dec 11, 14:12:30] #> checkpoint['batch'] = 44500
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# [Dec 11, 14:12:35] #> Note: Output directory /content already exists
#
#
#
#
# [Dec 11, 14:12:35] #> Creating directory /content/colbertindex
#
#
# [Dec 11, 14:14:24] [0] 		 #> Completed batch #0 (starting at passage #0) 		Passages/min: 38.5k (overall),  38.5k (this encoding),  93575.4M (this saving)
# [Dec 11, 14:14:24] [0] 		 #> Saved batch #0 to /content/colbertindex/0.pt 		 Saving Throughput = 8.6M passages per minute.
#
# [Dec 11, 14:16:10] [0] 		 #> Completed batch #1 (starting at passage #69905) 		Passages/min: 39.1k (overall),  39.8k (this encoding),  87960.8M (this saving)
# [Dec 11, 14:16:10] [0] 		 #> Saved batch #1 to /content/colbertindex/1.pt 		 Saving Throughput = 9.3M passages per minute.
#
# [Dec 11, 14:18:28] [0] 		 #> Completed batch #2 (starting at passage #139810) 		Passages/min: 35.6k (overall),  30.4k (this encoding),  91151.1M (this saving)
# [Dec 11, 14:18:28] [0] 		 #> Saved batch #2 to /content/colbertindex/2.pt 		 Saving Throughput = 9.5M passages per minute.
#
# [Dec 11, 14:20:14] [0] 		 #> Completed batch #3 (starting at passage #209715) 		Passages/min: 36.5k (overall),  39.7k (this encoding),  78536.5M (this saving)
# [Dec 11, 14:20:14] [0] 		 #> Saved batch #3 to /content/colbertindex/3.pt 		 Saving Throughput = 10.0M passages per minute.
#
# [Dec 11, 14:22:05] [0] 		 #> Completed batch #4 (starting at passage #279620) 		Passages/min: 36.8k (overall),  38.0k (this encoding),  97734.3M (this saving)
# [Dec 11, 14:22:05] [0] 		 #> Saved batch #4 to /content/colbertindex/4.pt 		 Saving Throughput = 8.8M passages per minute.
#
# [Dec 11, 14:23:35] [0] 		 #> Completed batch #5 (starting at passage #349525) 		Passages/min: 37.0k (overall),  38.5k (this encoding),  100857.3M (this saving)
# [Dec 11, 14:23:35] [0] 		 [NOTE] Done with local share.
# [Dec 11, 14:23:35] [0] 		 #> Joining saver thread.
# [Dec 11, 14:23:36] [0] 		 #> Saved batch #5 to /content/colbertindex/5.pt 		 Saving Throughput = 11.2M passages per minute.
#
# #> num_embeddings = 4491340
[tensor(0.0681), tensor(-0.0084), tensor(0.11...  20.966112   96447
# 895   [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  20.489077  364802
# 1443  [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  20.480770   72322
# 1459  [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  20.292057   72331
# 1445  [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  19.768444   72320
# 435   [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  19.053411  329831
# 719   [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  18.930492   72324
# 933   [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  18.748795   70074
# 2164  [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  18.676014  272952
# 2159  [[tensor(0.0681), tensor(-0.0084), tensor(0.11...  18.503189  272948
#
#       rank
# 5246     0
# 895      1
# 1443     2
# 1459     3
# 1445     4
# 435      5
# 719      6
# 933      7
# 2164     8
# 2159     9

# %%
type((colbert_e2e % 10).search("chemical reactions"))
# Out:
# pandas.core.frame.DataFrame

# %%
from train import *
from graph import *
from utils import get_hit
import sys
import re

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
bert = BertModel.from_pretrained("bert-base-uncased")
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
node_edge_detector = NodeEdgeDetector(bert, tokenizer, dropout=torch.tensor(0.5))
optimizer = AdamW
kw = {'lr':0.0002, 'weight_decay':0.1}
tl = TrainingLoop(node_edge_detector, optimizer, True, **kw)
loss = mse_loss
tl.load()
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
test_df = pd.read_excel('/content/BERT-QA/data/test.xlsx')
actual = test_df['Reverb_no'].to_list()
system_results = []
for index, row in tqdm(test_df.iterrows(), total=test_df.shape[0]):
  node, edge = tl.readable_predict(device, _input=row['Question'], print_result=False)
  node = ' '.join(node); edge = ' '.join(edge)
  node = node.replace(' ##', ''); edge = edge.replace(' ##', '')
  if index%1000 == 0:
    print(f"Question Number {index+1}: ", row['Question'].lower().split())
    print(f'Node: {node}, Edge: {edge}')
  q = ' '.join([node, edge])
  q = re.sub(r'[^\w]', ' ', q)
  temp = (colbert_e2e % 10).search(q)['docno'].to_list()
  temp = [[int(item)] for item in temp]
  system_results.append(temp)
  
print(get_hit(actual, system_results))
# Out:
#   0%|          | 0/5003 [00:00<?, ?it/s]
# Question Number 1:  ['how', 'do', 'protocols', 'vary']
# Node: protocols, Edge: do vary
#  20%|█▉        | 1000/5003 [08:07<29:04,  2.29it/s]
# Question Number 1001:  ['who', 'broke', 'his', 'silence', 'on', 'plath']
# Node: plath, Edge: broke his silence on
#  40%|███▉      | 2000/5003 [16:04<24:55,  2.01it/s]
# Question Number 2001:  ['where', 'is', 'bone', 'grafting', 'used']
# Node: bone grafting, Edge: is used
#  60%|█████▉    | 3000/5003 [24:05<13:31,  2.47it/s]
# Question Number 3001:  ['of', 'what', 'does', 'ironpython', 'make', 'extensive', 'use']
# Node: ironpython, Edge: of does make extensive use
#  80%|███████▉  | 4000/5003 [32:00<06:44,  2.48it/s]
# Question Number 4001:  ['in', 'what', 'is', 'oliver', 'wounded']
# Node: oliver, Edge: in is wounded
# 100%|█████████▉| 5000/5003 [40:00<00:01,  1.84it/s]
# Question Number 5001:  ['what', 'is', 'louise']
# Node: louise, Edge: is
# 100%|██████████| 5003/5003 [40:02<00:00,  2.08it/s]
# (0.7507495502698381, 0.897861283230062, 0.9250449730161903, 0.9524285428742755, 0.9524285428742755)
